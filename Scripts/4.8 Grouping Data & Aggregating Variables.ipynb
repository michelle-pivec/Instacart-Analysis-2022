# %% [markdown]
# # 01 Import libraries and data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Set path
path = r"C:\Users\miche\Instacart Basket Analysis 2022_MP\02 Data"

# %%
# Import pkl (df_derived = orders_produces_derived.pkl from tast 4.7)
derived = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_derived.pkl'))

# %%
# Explore data

# %%
derived.head()
# Out:
#    order_id  customer_id  order_number  order_day  order_hour  previous_order  \
# 0   2539329            1             1          2           8             NaN
# 1   3169664          363             9          5          14             8.0
# 2    554620         1357             4          4          15            30.0
# 3   2927564         1357             6          4           9            30.0
# 4   1028773         1960            13          0          19            16.0
#
#    product_id  add_to_cart_order  reordered                product_name  \
# 0       26088                  4          0  Aged White Cheddar Popcorn
# 1       26088                 19          0  Aged White Cheddar Popcorn
# 2       26088                  1          1  Aged White Cheddar Popcorn
# 3       26088                  3          1  Aged White Cheddar Popcorn
# 4       26088                  5          1  Aged White Cheddar Popcorn
#
#    department_id  prices _merge        price_range        busy_day  \
# 0             19     4.7   both  Low-range product  Regularly busy
# 1             19     4.7   both  Low-range product  Regularly busy
# 2             19     4.7   both  Low-range product      Least busy
# 3             19     4.7   both  Low-range product      Least busy
# 4             19     4.7   both  Low-range product     Busiest day
#
#         busy_days      busy_hours
# 0  Regularly busy  Average orders
# 1      Least busy     Most orders
# 2      Least busy     Most orders
# 3      Least busy     Most orders
# 4     Busiest day  Average orders

# %%
derived.columns
# Out:
# Index(['order_id', 'customer_id', 'order_number', 'order_day', 'order_hour',
#        'previous_order', 'product_id', 'add_to_cart_order', 'reordered',
#        'product_name', 'department_id', 'prices', '_merge', 'price_range',
#        'busy_day', 'busy_days', 'busy_hours'],
#       dtype='object')

# %%
derived.shape
# Out:
# (6481355, 17)

# %% [markdown]
# # 2 Aggregating data with agg( )

# %%
# performing a single aggregation
derived.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.458194
# 2                16.876030
# 3                17.103005
# 4                17.811421
# 5                15.267666
# 6                16.457281
# 7                17.242568
# 8                15.460554
# 9                15.955104
# 10               19.906733
# 11               16.186501
# 12               15.861564
# 13               16.570208
# 14               16.772875
# 15               16.139515
# 16               17.683961
# 17               15.722692
# 18               19.446872
# 19               17.183289
# 20               16.526508
# 21               22.762749

# %%
# Another way to performe aggregation
derived.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.458194
# 2     16.876030
# 3     17.103005
# 4     17.811421
# 5     15.267666
# 6     16.457281
# 7     17.242568
# 8     15.460554
# 9     15.955104
# 10    19.906733
# 11    16.186501
# 12    15.861564
# 13    16.570208
# 14    16.772875
# 15    16.139515
# 16    17.683961
# 17    15.722692
# 18    19.446872
# 19    17.183289
# 20    16.526508
# 21    22.762749
# Name: order_number, dtype: float64

# %%
# Performing multiple aggregations
derived.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.458194   1  99
# 2                16.876030   1  99
# 3                17.103005   1  99
# 4                17.811421   1  99
# 5                15.267666   1  99
# 6                16.457281   1  99
# 7                17.242568   1  99
# 8                15.460554   1  99
# 9                15.955104   1  99
# 10               19.906733   1  99
# 11               16.186501   1  99
# 12               15.861564   1  99
# 13               16.570208   1  99
# 14               16.772875   1  99
# 15               16.139515   1  99
# 16               17.683961   1  99
# 17               15.722692   1  99
# 18               19.446872   1  99
# 19               17.183289   1  99
# 20               16.526508   1  99
# 21               22.762749   1  99

# %% [markdown]
# # 3 Aggregating Data with transform( )

# %%
# Create max_order column populated with customer_id's max order count
derived['max_order'] = derived.groupby(['customer_id'])['order_number'].transform(np.max)

# %%
# Confirm transformation
derived.head()
# Out:
#    order_id  customer_id  order_number  order_day  order_hour  previous_order  \
# 0   2539329            1             1          2           8             NaN
# 1   3169664          363             9          5          14             8.0
# 2    554620         1357             4          4          15            30.0
# 3   2927564         1357             6          4           9            30.0
# 4   1028773         1960            13          0          19            16.0
#
#    product_id  add_to_cart_order  reordered                product_name  \
# 0       26088                  4          0  Aged White Cheddar Popcorn
# 1       26088                 19          0  Aged White Cheddar Popcorn
# 2       26088                  1          1  Aged White Cheddar Popcorn
# 3       26088                  3          1  Aged White Cheddar Popcorn
# 4       26088                  5          1  Aged White Cheddar Popcorn
#
#    department_id  prices _merge        price_range        busy_day  \
# 0             19     4.7   both  Low-range product  Regularly busy
# 1             19     4.7   both  Low-range product  Regularly busy
# 2             19     4.7   both  Low-range product      Least busy
# 3             19     4.7   both  Low-range product      Least busy
# 4             19     4.7   both  Low-range product     Busiest day
#
#         busy_days      busy_hours  max_order
# 0  Regularly busy  Average orders         10
# 1      Least busy     Most orders         12
# 2      Least busy     Most orders          7
# 3      Least busy     Most orders          7
# 4     Busiest day  Average orders         17

# %% [markdown]
# # 4 Deriving Columns with loc( )

# %%
# Assign loyalty_flags based on customers max_order
derived.loc[derived['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
derived.loc[(derived['max_order'] <= 40) & (derived['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
derived.loc[derived['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
derived['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    3158817
# Loyal customer      2045740
# New customer        1276798
# Name: loyalty_flag, dtype: int64

# %%
derived[['customer_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     customer_id      loyalty_flag  order_number
# 0             1      New customer             1
# 1           363  Regular customer             9
# 2          1357      New customer             4
# 3          1357      New customer             6
# 4          1960  Regular customer            13
# 5          2556    Loyal customer            17
# 6          3010  Regular customer            11
# 7          3393  Regular customer             6
# 8          3672  Regular customer             5
# 9          4083      New customer             1
# 10         4208    Loyal customer            27
# 11         5341  Regular customer             7
# 12         5771      New customer             5
# 13         6018      New customer             1
# 14         7025    Loyal customer            35
# 15         7025    Loyal customer            41
# 16         8377  Regular customer             5
# 17         8703    Loyal customer            93
# 18        10789  Regular customer            11
# 19        12172  Regular customer            16
# 20        12528  Regular customer             7
# 21        13124  Regular customer             8
# 22        13919  Regular customer            22
# 23        15097      New customer             5
# 24        15175    Loyal customer            20
# 25        15730    Loyal customer            13
# 26        15730    Loyal customer            14
# 27        15730    Loyal customer            15
# 28        16025  Regular customer            19
# 29        16336      New customer             5
# 30        16336      New customer            10
# 31        16939  Regular customer            14
# 32        16989    Loyal customer            25
# 33        16989    Loyal customer            46
# 34        18040      New customer             5
# 35        18123      New customer             2
# 36        18167      New customer             5
# 37        18631    Loyal customer            36
# 38        18631    Loyal customer            43
# 39        18631    Loyal customer            45
# 40        18631    Loyal customer            47
# 41        18631    Loyal customer            87
# 42        18631    Loyal customer            88
# 43        18631    Loyal customer            91
# 44        19226  Regular customer             9
# 45        19226  Regular customer            16
# 46        21035      New customer             2
# 47        21038  Regular customer             6
# 48        21219    Loyal customer            31
# 49        22728  Regular customer            16
# 50        23135  Regular customer             8
# 51        23190    Loyal customer            12
# 52        23190    Loyal customer            13
# 53        23190    Loyal customer            33
# 54        23190    Loyal customer            39
# 55        23190    Loyal customer            62
# 56        24412    Loyal customer             9
# 57        24412    Loyal customer            19
# 58        24850  Regular customer             7
# 59        25590      New customer             3

# %% [markdown]
# # Task, Steps 5 - 9
# #### Steps 1-4 performed above

# %%
# 5 Find the difference between spending habits based on customers loyalty flag 
derived.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.525109  1.0  99999.0
# New customer      13.252656  1.0  99999.0
# Regular customer  12.792695  1.0  99999.0

# %%
# 6 Create a spending flag for High and Low spenders (criteria: customers' average price per product <10 = Low spendder, >=10 = High spender)
# create average_price column
derived['average_price']=derived.groupby(['customer_id'])['prices'].transform(np.mean)

# %%
# Create a flag that assigns a “types of spenders” label to a user ID based on average prices.
derived.loc[derived['average_price'] < 10, 'spender_flag'] = 'Low spender'
derived.loc[derived['average_price'] >= 10, 'spender_flag'] = 'High spender'

# %%
# Confirm spender_flag count
derived['spender_flag'].value_counts(dropna=False)
# Out:
# Low spender     6323259
# High spender     158096
# Name: spender_flag, dtype: int64

# %%
# 7 Create customer_frequency flag
# create median_previous_oder column based on customers previous_orders 
derived['median_previous_order'] = derived.groupby(['customer_id'])['previous_order'].transform(np.median)

# %%
# create flags with criteria based on median_previous_order
derived.loc[derived['median_previous_order']>20, 'customer_frequency'] = 'Non-frequent customer'
derived.loc[(derived['median_previous_order']>10) & (derived['median_previous_order']<=20), 'customer_frequency'] = 'Regular customer'
derived.loc[derived['median_previous_order']<=10, 'customer_frequency'] = 'Frequent customer'

# %%
derived['customer_frequency'].value_counts(dropna=False)
# Out:
# Frequent customer        4296048
# Regular customer         1434032
# Non-frequent customer     748236
# NaN                         3039
# Name: customer_frequency, dtype: int64

# %%
#8 Review data
derived.shape
# Out:
# (6481355, 23)

# %%
derived.columns
# Out:
# Index(['order_id', 'customer_id', 'order_number', 'order_day', 'order_hour',
#        'previous_order', 'product_id', 'add_to_cart_order', 'reordered',
#        'product_name', 'department_id', 'prices', '_merge', 'price_range',
#        'busy_day', 'busy_days', 'busy_hours', 'max_order', 'loyalty_flag',
#        'average_price', 'spender_flag', 'median_previous_order',
#        'customer_frequency'],
#       dtype='object')

# %%
derived.head()
# Out:
#    order_id  customer_id  order_number  order_day  order_hour  previous_order  \
# 0   2539329            1             1          2           8             NaN
# 1   3169664          363             9          5          14             8.0
# 2    554620         1357             4          4          15            30.0
# 3   2927564         1357             6          4           9            30.0
# 4   1028773         1960            13          0          19            16.0
#
#    product_id  add_to_cart_order  reordered                product_name  ...  \
# 0       26088                  4          0  Aged White Cheddar Popcorn  ...
# 1       26088                 19          0  Aged White Cheddar Popcorn  ...
# 2       26088                  1          1  Aged White Cheddar Popcorn  ...
# 3       26088                  3          1  Aged White Cheddar Popcorn  ...
# 4       26088                  5          1  Aged White Cheddar Popcorn  ...
#
#          price_range        busy_day       busy_days      busy_hours  \
# 0  Low-range product  Regularly busy  Regularly busy  Average orders
# 1  Low-range product  Regularly busy      Least busy     Most orders
# 2  Low-range product      Least busy      Least busy     Most orders
# 3  Low-range product      Least busy      Least busy     Most orders
# 4  Low-range product     Busiest day     Busiest day  Average orders
#
#   max_order      loyalty_flag average_price  spender_flag  \
# 0        10      New customer      6.010000   Low spender
# 1        12  Regular customer      8.413158   Low spender
# 2         7      New customer      3.930000   Low spender
# 3         7      New customer      3.930000   Low spender
# 4        17  Regular customer      5.684211   Low spender
#
#   median_previous_order     customer_frequency
# 0                  21.0  Non-frequent customer
# 1                   8.0      Frequent customer
# 2                  30.0  Non-frequent customer
# 3                  30.0  Non-frequent customer
# 4                  19.0       Regular customer
#
# [5 rows x 23 columns]

# %%
# Export dataframe to pkl
derived.to_pickle(os.path.join(path,'Prepared Data', 'orders_products_flags.pkl'))
